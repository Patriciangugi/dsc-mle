# %% [markdown]
# <a href="https://colab.research.google.com/github/Patriciangugi/dsc-mle/blob/master/Maximum_Likelihood_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def coinToss():
    number = int(input("Number of times to flip coin: "))
    recordList = []
    heads = 0
    tails = 0
    for amount in range(number):
        flip = random.randint(0, 1)
        if flip == 0:
            print("Toss", amount+1, ':', "Heads")
            recordList.append("Heads")
        else:
            print("Toss", amount+1, ':', "Tails")
            recordList.append("Tails")
    print(str(recordList))
    print(str(recordList.count("Heads")) + " Heads, " + str(recordList.count("Tails")) + " Tails")
    return recordList

# %%
first = coinToss() # Capitalize the T in 'coinToss' to match the function definition.
# Out:
# Number of times to flip coin: 100
# Toss 1 : Tails
# Toss 2 : Tails
# Toss 3 : Tails
# Toss 4 : Heads
# Toss 5 : Heads
# Toss 6 : Heads
# Toss 7 : Heads
# Toss 8 : Tails
# Toss 9 : Tails
# Toss 10 : Tails
# Toss 11 : Tails
# Toss 12 : Heads
# Toss 13 : Tails
# Toss 14 : Tails
# Toss 15 : Heads
# Toss 16 : Heads
# Toss 17 : Heads
# Toss 18 : Heads
# Toss 19 : Heads
# Toss 20 : Heads
# Toss 21 : Heads
# Toss 22 : Heads
# Toss 23 : Heads
# Toss 24 : Tails
# Toss 25 : Tails
# Toss 26 : Heads
# Toss 27 : Heads
# Toss 28 : Tails
# Toss 29 : Heads
# Toss 30 : Heads
# Toss 31 : Tails
# Toss 32 : Heads
# Toss 33 : Heads
# Toss 34 : Tails
# Toss 35 : Heads
# Toss 36 : Heads
# Toss 37 : Tails
# Toss 38 : Heads
# Toss 39 : Tails
# Toss 40 : Heads
# Toss 41 : Tails
# Toss 42 : Tails
# Toss 43 : Tails
# Toss 44 : Heads
# Toss 45 : Tails
# Toss 46 : Tails
# Toss 47 : Heads
# Toss 48 : Heads
# Toss 49 : Heads
# Toss 50 : Heads
# Toss 51 : Tails
# Toss 52 : Heads
# Toss 53 : Heads
# Toss 54 : Heads
# ...

# %%
first = coinToss() # Capitalize the T in 'coinToss' to match the function definition.
p_head = first.count('Heads') / len(first) # Use 'first' and divide by the length of the list
print(p_head)
# Out:
# Number of times to flip coin: 100
# Toss 1 : Tails
# Toss 2 : Heads
# Toss 3 : Tails
# Toss 4 : Heads
# Toss 5 : Tails
# Toss 6 : Heads
# Toss 7 : Heads
# Toss 8 : Heads
# Toss 9 : Heads
# Toss 10 : Heads
# Toss 11 : Tails
# Toss 12 : Heads
# Toss 13 : Heads
# Toss 14 : Heads
# Toss 15 : Tails
# Toss 16 : Heads
# Toss 17 : Tails
# Toss 18 : Heads
# Toss 19 : Tails
# Toss 20 : Heads
# Toss 21 : Heads
# Toss 22 : Heads
# Toss 23 : Heads
# Toss 24 : Heads
# Toss 25 : Tails
# Toss 26 : Heads
# Toss 27 : Heads
# Toss 28 : Tails
# Toss 29 : Tails
# Toss 30 : Heads
# Toss 31 : Tails
# Toss 32 : Heads
# Toss 33 : Heads
# Toss 34 : Heads
# Toss 35 : Heads
# Toss 36 : Tails
# Toss 37 : Heads
# Toss 38 : Heads
# Toss 39 : Tails
# Toss 40 : Heads
# Toss 41 : Heads
# Toss 42 : Tails
# Toss 43 : Tails
# Toss 44 : Tails
# Toss 45 : Tails
# Toss 46 : Tails
# Toss 47 : Tails
# Toss 48 : Tails
# Toss 49 : Heads
# Toss 50 : Tails
# Toss 51 : Tails
# Toss 52 : Heads
# Toss 53 : Heads
# Toss 54 : Tails
# ...
